# %%
# %matplotlib inline

# %%
ls
# Out:
# profile_p_omega_k_nut.xy  wallShearStress_wallboundary.raw
# U_WSdata.xy.org           wallShearStress_wallboundary.raw.org
# U_WS.xy                   yp_of.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0.1,1000,10000)

# %%
yp=x
up=yp

# %%
plt.plot(yp,up)
plt.xscale('log')

# %%
yp=x
up=(1.0/0.41)*np.log(yp)+5.0

# %%
plt.plot(yp,up)
plt.xscale('log')

# %%
yp=x
up=yp
up1=(1.0/0.41)*np.log(yp)+5.0

# %%
plt.plot(yp,up)
plt.plot(yp,up1)
plt.xscale('log')
plt.ylim(0,25)
# Out:
# (0, 25)

# %%
#data = np.loadtxt("U_WSdata.xy",skiprows=0,dtype=str)
#data = np.loadtxt("U_WSdata.xy",skiprows=0)
data = np.loadtxt("U_WS.xy",skiprows=0)
ws = np.sqrt(data[:,4]**2 + data[:,5]**2 + data[:,6]**2)
um = np.sqrt(data[:,1]**2 + data[:,2]**2 + data[:,3]**2)

# %%
#data[0:1,0]

# %%
#plt.plot(ws,data[:,0],'-o')
#plt.xlim(-0.0001,0.0001)
#plt.ylim(0,0.01)

# %%
nu=4.0e-07
rho=1.0

# %%
#maximum ws or ws at wall
wsm=np.max(ws)

# %%
wsm
# Out:
# 0.00086021280600272199

# %%
#From paraview or adjusted
#wsm=0.0014
#wsm=0.00135
wsm=0.001317
wsm=0.001595

# %%
#wsm=np.sqrt( (-0.00190634)**2 + (-1.01361e-08)**2 + 0**2)
wsm=np.sqrt( (-0.00117326)**2 + (0.000143495)**2 + 0**2)

# %%
wsm
# Out:
# 0.001595

# %%
#utau=np.sqrt(ws/rho)
utau=np.sqrt(wsm/rho)

# %%
#utau

# %%
ypn=utau*data[:,0]/nu

# %%
upn=um/utau

# %%
plt.figure(figsize=(14, 8))

plt.plot(yp,up)
plt.plot(yp,up1)

#plt.plot(ypn,upn,'-o',ms=6)
plt.plot(ypn,upn,'-')

plt.xscale('log')
plt.ylim(0,40)

plt.grid()

# %%
data1 = np.loadtxt("wallShearStress_wallboundary.raw",skiprows=0)

# %%
data1[:,0]
# Out:
# array([-0.00861857, -0.00355779, -0.0032857 , -0.00336545, -0.00332905,
#        -0.00322788, -0.00311859, -0.00301666, -0.00292312, -0.00283703,
#        -0.00275807, -0.00268595, -0.00262019, -0.00256018, -0.00250526,
#        -0.00245458, -0.00240761, -0.00236414, -0.00232383, -0.00228633,
#        -0.00225133, -0.0022186 , -0.00218789, -0.00215903, -0.00213183,
#        -0.0021061 , -0.00208161, -0.00205821, -0.00203585, -0.00201448,
#        -0.00199401, -0.00197439, -0.00195557, -0.00193749, -0.00192009,
#        -0.00190329, -0.00188698, -0.0018712 , -0.00185594, -0.00184116,
#        -0.00182682, -0.00181291, -0.00179938, -0.00178621, -0.00177339,
#        -0.00176089, -0.00174869, -0.00173678, -0.00172513, -0.00171373,
#        -0.00170258, -0.00169165, -0.00168094, -0.00167043, -0.00166011,
#        -0.00164999, -0.00164003, -0.00163025, -0.00162063, -0.00161117,
#        -0.00160186, -0.00159269, -0.00158365, -0.00157476, -0.00156599,
# ...

# %%
np.argmin(np.abs(data1[:,0] - 0.0013))
# Out:
# 0

# %%
np.argmin(np.abs(data1[:,0]))
# Out:
# 0

# %%
from scipy import interpolate
fint = interpolate.interp1d(data1[:,0],data1[:,3],kind='linear')

# %%
fint[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-56f4f8c2c55c> in <module>()
# ----> 1 fint[0]
#
# TypeError: 'interp1d' object does not support indexing
